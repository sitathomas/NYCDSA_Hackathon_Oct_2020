# %% [markdown]
# ## Setup and Data Import

# %%
import sys
sys.path.insert(0, '..')

import Functions as fxns

from Functions import pd
pd.set_option('display.max_columns', None)

import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('dark_background')

# %%
fxns.merge_dfs()

df = pd.read_csv('../data/kkbox_merged.csv')

# %%
print(df.shape)
df.columns
# Out:
# (335947, 23)
# Index(['msno', 'is_churn', 'city', 'bd', 'gender', 'registered_via',
#        'registration_init_time', 'payment_method_id', 'payment_plan_days',
#        'plan_list_price', 'actual_amount_paid', 'is_auto_renew',
#        'transaction_date', 'membership_expire_date', 'is_cancel', 'date',
#        'num_25', 'num_50', 'num_75', 'num_985', 'num_100', 'num_unq',
#        'total_secs'],
#       dtype='object')

# %%
df.sample(10)
# Out:
#                                                 msno  is_churn  city  bd  \
# 170866  2+2cFvSLr3PG9kDnJIVhwSohxfayQGZam3iomdQCicA=         0    11  25
# 92261   LEegyDHpit60k9Y8+sJsnlOUMQ8O9pjm7IMVnm708XU=         0     1   0
# 174432  bUtsUMU53IlkM89Nf1GZN53E+Nt+mEh//QaftFQyYOk=         0    15  30
# 270150  3eURA4XmAQvcP5b0P3aOsEa2ZeCQrMK3Y0MS7daQtBg=         0     5  21
# 227283  eWkNgeBCy0Dv1E8isJGckgsXcV9hUWu5KuhRLkn0LLs=         0     1  24
# 222266  nYa6lA4JKQEUclojr/bfsNkfJf+IafUj8fhtmQ3sP5E=         0     5  18
# 34201   VSn264U2aGMyPxX/k8ddWGzJ25hPT1feo/leNvioW1c=         0     1   0
# 39827   N3ZsYawdwzbtPGRTAZk7lhzPCbxDzeslEGFgMh76MD0=         0    13  34
# 34332   KEAempm1tmX5D/VAcQZOWV0G7nODo4hpAvN+RcCympw=         0     7  26
# 322292  zn94q1jwwRmHt4a+Po/Kt4jl6+CjJr78fjw5fXOIM7Q=         0    10  22
#
#         gender  registered_via  registration_init_time  payment_method_id  \
# 170866    male               7                20150813                 41
# 92261      NaN               7                20161019                 41
# 174432    male               9                20100902                 39
# 270150  female               3                20131126                 39
# 227283    male               7                20160506                 41
# 222266  female               7                20151207                 41
# 34201      NaN               7                20160603                 41
# 39827   female               3                20140422                 31
# 34332     male               3                20131009                 37
# 322292  female               3                20130131                 37
#
#         payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 170866                 30              149                 149              1
# 92261                  30              149                 149              1
# 174432                 30              149                 149              1
# 270150                 30              149                 149              1
# 227283                 30              149                 149              1
# 222266                 30               99                  99              1
# 34201                  30               99                  99              1
# 39827                  30              149                 149              1
# 34332                  30              149                 149              1
# 322292                 30              149                 149              1
#
#         transaction_date  membership_expire_date  is_cancel      date  num_25  \
# 170866          20170312                20170412          0  20170326       1
# 92261           20170318                20170418          0  20170308      12
# 174432          20170228                20170430          0  20170315      41
# 270150          20170331                20170517          0  20170305       1
# 227283          20170305                20170405          0  20170331       1
# 222266          20170324                20170424          0  20170324      27
# 34201           20170303                20170403          0  20170314       1
# 39827           20170331                20170430          0  20170325       5
# 34332           20170326                20170425          0  20170321       0
# 322292          20170307                20170406          0  20170317       0
#
#         num_50  num_75  num_985  num_100  num_unq  total_secs
# 170866       2       1        0        8        9    2130.930
# 92261        0       2        0       14       28    4037.651
# 174432       5       2        4       92      104   22926.815
# 270150       1       1        0        9        4    2568.485
# 227283       2       1        0        4        5    1068.384
# 222266       2       3        1       48       68   14182.257
# 34201        2       0        0       18       20    4736.848
# 39827        0       0        1       18       19    5135.921
# 34332        2       1       10      100       75   28297.267
# 322292       1       0        0        3        4     843.342

# %%
# columns with missing values
print('Columns with missing values:\n', df.isna().any()[df.isna().any()])

print('\nPercent missingness in gender column:\n',
    (len(df.gender) - df.gender.value_counts().sum())
     / len(df.gender) * 100)
# Out:
# Columns with missing values:
#  gender    True
# dtype: bool
#
# Percent missingness in gender column:
#  46.23288792577401

# %% [markdown]
# ## Pre-processing

# %%
# use index as ID for tidiness
df = df.drop('msno', axis=1)

# %% [markdown]
# ## EDA

# %%
print('Churn percent:', df.is_churn.sum() / len(df) * 100)
# Out:
# Churn percent: 8.97820191875504
